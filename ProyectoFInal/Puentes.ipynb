# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="min"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Proyecto Final</p></tp>
#             <tp><p style="font-size:150%;text-align:center">Puentes de Königsberg</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # Objetivos <a class="anchor" id="inicio"></a>
#
# En este notebook se irá describiendo el paso a paso de la solución para los puentes de Konigsberg, el objetivo principal es encontrar al menos una fórmula en la que sea realizable el ejercicio. Dado el mapa de Königsberg, el río Prägel, que divide el plano en cuatro regiones distintas conectadas por siete puentes. Se quiere demostrar que camino(s) son posibles, comenzando a caminar desde cualquiera de estas regiones cruzando todos los puentes una sola vez y volviendo al mismo punto de partida.

# %% [markdown]
# # ¿Qué sucede en los puentes de  Königsberg? <a class="anchor" id="sat"></a>
#
#  El problema se formuló en el siglo XVIII y consistía en encontrar un recorrido para cruzar a pie toda la ciudad pasando solo una vez por cada uno de los puentes y regresando al mismo punto de inicio.
#
# Después de varios ensayos e investigación llegamos a resolver que es algo imposible, es necesario cruzar algún puente más de una vez. A base de repetir y repetir acabamos dándonos cuenta de que es un problema irresoluble. Ya que no existía ninguna manera en que se pudiesen atravesar los 7 puentes originales.
#
# <img src="./img/puentes_original.png" width="auto"/>
#
# A lo que, decidimos reducir la cantidad total de puentes a 5. Dando como esquema algo similar a lo siguiente:
#
# <img src="./img/hacible.jpeg" width="auto"/>

# %%
from Logica import *
import random
# Nx corresponde a la cantidad de puentes
# Turnos son la cantidad de turnos que puede tener la máquina
# Sentidos corresponde sentidos correspondientes a cada puente

Nx = 5
turnos = 5
sentidos = 2
turnillo = list(range(turnos))
numeros = list(range(Nx))
X = list(range(Nx))
Y = list(range(sentidos))
caminos = Descriptor([Nx, turnos, sentidos])

# %%
def SATtabla(self):
    letras = list(self.letras())
    n = len(letras)
    valores = list(product([True, False], repeat=n))
    for v in valores:
        I = {letras[x]: v[x] for x in range(n)}
        if self.valor(I):
            return I
    return None

# %% [markdown]
# # Reglas <a class="anchor" id="reglas"></a>
#
# 1. Se debe pasar por los cinco puentes.
# 2. No se puede pasar dos veces por el mismo puente.
# 3. Se inicia en la región A y se termina en la región D.
# 4. Conexión.
#
#
# 1. programar las reglas
# Se hará por profundidad primero

# %%
def escribir(self, literal):
    if '-' in literal:
        atomo = literal[1:]
        neg = ' no'
    else:
        atomo = literal
        neg = ''
    x, y, n  = self.inv(atomo)
    return f"El caminante, pasa por el puente {[x]}{neg} en el turno {[y]}, hacia la dirección{[n]}"

# caminos.escribir('-' + atomo)
from types import MethodType

caminos.escribir = MethodType(escribir, caminos)

# %%
# creación de los átomos

print("Cantidad de átomos Regla1:", caminos.rango[1] - caminos.rango[0])
print("Caracteres correspondientes a los átomos caminos:\n")
for t in range(turnos):
    for puente in range(Nx):
        for sentido in range(sentidos):
            atomo = caminos.P([puente, t, sentido])
            print(f"El caminante pasa en el turno {t}, por el puente {puente} en el sentido {sentido}, con el átomo {atomo}")
    print("")
# Out:
# Cantidad de átomos Regla1: 50
# Caracteres correspondientes a los átomos caminos:
#
# El caminante pasa en el turno 0, por el puente 0 en el sentido 0, con el átomo Ā
# El caminante pasa en el turno 0, por el puente 0 en el sentido 1, con el átomo ę
# El caminante pasa en el turno 0, por el puente 1 en el sentido 0, con el átomo ā
# El caminante pasa en el turno 0, por el puente 1 en el sentido 1, con el átomo Ě
# El caminante pasa en el turno 0, por el puente 2 en el sentido 0, con el átomo Ă
# El caminante pasa en el turno 0, por el puente 2 en el sentido 1, con el átomo ě
# El caminante pasa en el turno 0, por el puente 3 en el sentido 0, con el átomo ă
# El caminante pasa en el turno 0, por el puente 3 en el sentido 1, con el átomo Ĝ
# El caminante pasa en el turno 0, por el puente 4 en el sentido 0, con el átomo Ą
# El caminante pasa en el turno 0, por el puente 4 en el sentido 1, con el átomo ĝ
#
# ...

# %%
#Creación de puentes
#Sentido p es decir 0,0,0
#Sentido q es decir 0,0,1

atomo1 = caminos.P([0,0,0])
atomo2 = caminos.P([0,0,1])
puente0 = [atomo1, atomo2]
#Creacion de todos los puentes

#Para el puente 1 está el sentido r: (1,t,0) y el sentido s: (1,t,1)
atomoR = caminos.P([1,t,0])
atomoS = caminos.P([1,t,1])
puente1 = [atomoR, atomoS]

#Para el puente 2 está el sentido t: (2,t,0) y el sentido u: (2,t,1)
atomoT = caminos.P([2,t,0])
atomoU = caminos.P([2,t,1])
puente2 = [atomoT, atomoU]

#Para el puente 3 está el sentido x: (3,t,0) y el sentido y: (3,t,1)
atomoX = caminos.P([3,t,0])
#atomoY = atomoY0 #Ya fue previamente creado, solo es referenciado por orden.
#puente3 = [atomoX, atomoY]

#Para el puente 4 está el sentido b: (4,t,0) y el sentido c: (4,t,1)
#atomoB = atomoB #Fue creado previamente
atomoC = caminos.P([4,t,1])
#puente4 = [atomoB, atomoC]

# %%
#Creacion del puente 0 en todos los turnos posibles
atomoP = []
p = []

for turno in turnillo:
    atomoP.append((0, turnillo[turno], 0))

for i in atomoP:
    atomos_deP = caminos.P(i)
    for atomo in atomos_deP:
        #bundes = caminos.escribir(atomo)
        p.append(atomo)

print(p)

atomoQ = []
q = []

for turno in turnillo:
    atomoQ.append((0, turnillo[turno], 1))

for i in atomoQ:
    atomos_deQ = caminos.P(i)
    for atomo in atomos_deQ:
        #champ = caminos.escribir(atomo)
        q.append(atomo)
print(q)
# Out:
# ['Ā', 'ą', 'Ċ', 'ď', 'Ĕ']
# ['ę', 'Ğ', 'ģ', 'Ĩ', 'ĭ']

# %%
#Creación del puente 1 en todos los turnos posibles
atomoR = []
r = []
for turno in turnillo:
    atomoR.append((1, turnillo[turno], 0))

for i in atomoR:
    atomos_deR = caminos.P(i)
    for atomo in atomos_deR:
        #manutd = caminos.escribir(atomo)
        r.append(atomo)
print(r)

atomoS = []
s = []
for turno in turnillo:
    atomoS.append((1, turnillo[turno], 1))

for i in atomoS:
    atomos_deS = caminos.P(i)
    for atomo in atomos_deS:
        #mancity = caminos.escribir(atomo)
        s.append(atomo)
print(s)
# Out:
# ['ā', 'Ć', 'ċ', 'Đ', 'ĕ']
# ['Ě', 'ğ', 'Ĥ', 'ĩ', 'Į']

# %%
#Creación del puente 2 en todos los turnos posibles
atomoT = []
t = []
for turno in turnillo:
    atomoT.append((2, turnillo[turno], 0))

for i in atomoT:
    atomos_deT = caminos.P(i)
    for atomo in atomos_deT:
        #cristiano = caminos.escribir(atomo)
        t.append(atomo)
print(t)

atomoU = []
u = []
for turno in turnillo:
    atomoU.append((2, turnillo[turno], 1))

for i in atomoU:
    atomos_deU = caminos.P(i)
    for atomo in atomos_deU:
        #lio = caminos.escribir(atomo)
        u.append(atomo)

print(u)
# Out:
# ['Ă', 'ć', 'Č', 'đ', 'Ė']
# ['ě', 'Ġ', 'ĥ', 'Ī', 'į']

# %%
#Creación del puente 3 en todos los turnos posibles
atomoX = []
x = []
for turno in turnillo:
    atomoX.append((3, turnillo[turno], 0))

for i in atomoX:
    atomos_deX = caminos.P(i)
    for atomo in atomos_deX:
        #l = caminos.escribir(atomo)
        x.append(atomo)
print(x)
atomoY = []
y = []
for turno in turnillo:
    atomoY.append((3, turnillo[turno], 1))

for i in atomoY:
    atomos_deY = caminos.P(i)
    for atomo in atomos_deY:
        #mbape = caminos.escribir(atomo)
        y.append(atomo)
print(y)
# Out:
# ['ă', 'Ĉ', 'č', 'Ē', 'ė']
# ['Ĝ', 'ġ', 'Ħ', 'ī', 'İ']

# %%
#Creación del puente 4 en todos los turnos posibles
atomoB = []
b = []
for turno in turnillo:
    atomoB.append((4, turnillo[turno], 0)) #Crea una lista de tuplas con todos los turnos en B

for i in atomoB:
    atomos_deB = caminos.P(i)
    for atomo in atomos_deB:
        #a = caminos.escribir(atomo)
        b.append(atomo)
print(b)

atomoC = []
c = []
for turno in turnillo:
    atomoC.append((4, turnillo[turno], 1)) #Crea una lista de tuplas con todos los turnos en B

for i in atomoC:
    atomos_deC = caminos.P(i)
    for atomo in atomos_deC:
        #n = caminos.escribir(atomo)
        c.append(atomo)
print(c)
# Out:
# ['Ą', 'ĉ', 'Ď', 'ē', 'Ę']
# ['ĝ', 'Ģ', 'ħ', 'Ĭ', 'ı']

# %% [markdown]
# # Regla 1
# $$ \bigwedge_{{i}\in\texttt{T}} (p_i \vee q_i) \wedge \bigwedge_{{i}\in\texttt{T}} (s_i \vee r_i) \wedge \bigwedge_{{i}\in\texttt{T}}(u_i \vee t_i) \wedge \bigwedge_{{i}\in\texttt{T}}(y_i \vee x_i) \wedge \bigwedge_{{i}\in\texttt{T}}(b_i \vee c_i) $$

# %%
regla1 = ''

regla1_pyQ0 = "(" + "("+ "(" + p[0] + "O" + p[1] + ")" + "O" +"("+ p[2] + "O" + p[3] + ")" + ")" + "O" + "(" + p[4]+  "O" + q[0] + ")" + ")"
regla1_Q1 = "("+ "(" + q[1] + "O" + q[2] + ")" + "O" +"("+q[3] + "O" + q[4] + ")" + ")"
regla1_pq =[regla1_pyQ0, regla1_Q1]
otoriapq = Otoria(regla1_pq)
#print(otoriapq)

regla1_R =  "(" + "("+ "(" + r[0] + "O" + r[1] + ")" + "O" +"("+ r[2] + "O" + r[3] + ")" + ")" + "O" + "(" + r[4]+  "O" + s[0] + ")" + ")"
regla1_S =  "("+ "(" + s[1] + "O" + s[2] + ")" + "O" +"("+ s[3] + "O" + s[4] + ")" + ")"
regla1_rs = [regla1_S, regla1_R]
otoriars = Otoria(regla1_rs)
#print(otoriars)

regla1_T = "(" + "("+ "(" + t[0] + "O" + t[1] + ")" + "O" +"("+ t[2] + "O" +t[3] + ")" + ")" + "O" + "(" + t[4]+  "O" + u[0] + ")" + ")"
regla1_U = "("+ "(" + u[1] + "O" + u[2] + ")" + "O" +"("+ u[3] + "O" + u[4] + ")" + ")"
regla1_tu = [regla1_T, regla1_U]
otoriatu = Otoria(regla1_tu)
#print(otoriatu)

regla1_X = "(" + "("+ "(" + x[0] + "O" + x[1] + ")" + "O" +"("+ x[2] + "O" + x[3] + ")" + ")" + "O" + "(" + x[4]+  "O" + y[0] + ")" + ")"
regla1_Y = "("+ "(" + y[1] + "O" + y[2] + ")" + "O" +"("+ y[3] + "O" + y[4] + ")" + ")"
regla1_XY = [regla1_Y, regla1_X]
otoriaXY = Otoria(regla1_XY)
#print(otoriaXY)

regla1_B = "(" + "("+ "(" + b[0] + "O" + b[1] + ")" + "O" +"("+ b[2] + "O" + b[3] + ")" + ")" + "O" + "(" + b[4]+  "O" + c[0] + ")" + ")"
regla1_C = "("+ "(" + c[1] + "O" + c[2] + ")" + "O" +"("+ c[3] + "O" + c[4] + ")" + ")"
regla1_BC = [regla1_B, regla1_C]
otoriaBC = Otoria(regla1_BC)
#print(otoriaBC)

lista_otorias = [otoriapq, otoriars, otoriatu, otoriaXY, otoriaBC]
ytoria_regla1 = Ytoria(lista_otorias)
print(ytoria_regla1)

contador_parentesis = 0
string_regla1 = ''
for i in ytoria_regla1:
    if i == "(":
        string_regla1 += i
        contador_parentesis += 1
    elif i == "O":
        string_regla1 += i
    elif i == "Y":
        string_regla1 += i
    elif i == ")":
        string_regla1 += i
        contador_parentesis += 1
    else:
        n = caminos.escribir(i)
        string_regla1 += n

#print(contador_parentesis)
#print(string_regla1)
#regla1
A = inorder_to_tree(ytoria_regla1)
#print(A)
B = tseitin(ytoria_regla1)
L = {}
dpll(B, L)
#SATtabla(A)
#forms = A
#forms = [A(f) for f in forms]


#SATtabla(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 regla1 = ''
# ----> 3 regla1_pyQ0 = "(" + "("+ "(" + p[0] + "O" + p[1] + ")" + "O" +"("+ p[2] + "O" + p[3] + ")" + ")" + "O" + "(" + p[4]+  "O" + q[0] + ")" + ")"
#       4 regla1_Q1 = "("+ "(" + q[1] + "O" + q[2] + ")" + "O" +"("+q[3] + "O" + q[4] + ")" + ")"
#       5 regla1_pq =[regla1_pyQ0, regla1_Q1]
#
# NameError: name 'p' is not defined

# %% [markdown]
# # Regla 2
#
# $$ \left(\bigvee_{{i}\in\texttt{T}} (p_i \to \bigwedge_{{j}\in\texttt{T}} \neg p_j \wedge \neg q_j) \vee
# \bigvee_{{i}\in\texttt{T}} (q_i \to \bigwedge_{{j}\in\texttt{T}} \neg q_j \wedge \neg p_j)\right) \vee
# \left(\bigvee_{{i}\in\texttt{T}} (s_i \to \bigwedge_{{j}\in\texttt{T}} \neg s_j \wedge \neg r_i) \vee
# \bigvee_{{i}\in\texttt{T}} (r_i \to \bigwedge_{{j}\in\texttt{T}} \neg r_j \wedge \neg s_j)\right) \vee
# \left(\bigvee_{{i}\in\texttt{T}} (u_i \to \bigwedge_{{j}\in\texttt{T}} \neg u_j \wedge \neg t_j) \vee
# \bigvee_{{i}\in\texttt{T}} (t_i \to \bigwedge_{{j}\in\texttt{T}} \neg t_j \wedge \neg u_j)\right) \vee  $$

# %% [markdown]
# $$ \left(\bigvee_{{i}\in\texttt{T}} (y_i \to \bigwedge_{{j}\in\texttt{T}} \neg y_j \wedge \neg x_j) \vee
# \bigvee_{{i}\in\texttt{T}} (x_i \to \bigwedge_{{j}\in\texttt{T}} \neg x_j \wedge \neg y_j)\right) \vee
# \left(\bigvee_{{i}\in\texttt{T}} (b_i \to \bigwedge_{{j}\in\texttt{T}} \neg b_j \wedge \neg c_j) \vee
# \bigvee_{{i}\in\texttt{T}} (c_i \to \bigwedge_{{j}\in\texttt{T}} \neg c_j \wedge \neg b_j)\right) $$

# %%
#Creación de puentes
#Sentido p es decir 0,0,0
#Sentido q es decir 0,0,1
atomo1 = caminos.P([0,0,0])
atomo2 = caminos.P([0,0,1])
puente1 = [atomo1, atomo2]
#Creacion de todos los puentes
#atomo1_en_turno_aleatorio = caminos.P([0,t,0])
#atomo2_en_turno_aleatorio = caminos.P([0,t,1])

#Creacion puente 3: el sentido x es el 3,t,0 y el sentido y es 3,t,1
#atomoX = caminos.P([3,t,0])
#atomoY = caminos.P([3,t,1])
#Creacion Puente 4: En el sentido b es el 4,t,0 y en el sentido c es 4,t,1
#atomoB = caminos.P([4,t,0])
#atomoC = caminos.P([4,t,1])
#Sentido B en el turno 0
atomoB0 =caminos.P([4,0,0])
sentidoB_en_diferentes_turnos = [caminos.P([4,1,0]), caminos.P([4,2,0]), caminos.P([4,3,0]), caminos.P([4,4,0])]
#Pasa por Y en el turno 0
atomoY0 = caminos.P([3,0,1])
sentidoY_en_diferentes_turnos = [caminos.P([3,1,1]), caminos.P([3,2,1]), caminos.P([3,3,1]), caminos.P([3,4,1])]
#Creación de los sentidos en diferentes turnos del puente 1
sentidop_en_diferentes_turnos = [caminos.P([0,1,0]), caminos.P([0,2,0]), caminos.P([0,3,0]),caminos.P([0,4,0])]
sentidoq_en_diferentes_turnos = [caminos.P([0,1,1]), caminos.P([0,2,1]), caminos.P([0,3,1]), caminos.P([0,4,1])]

#print(sentidoY_en_diferentes_turnos)
#Creación que debe comenzar por Y, P, B
sentido_p_en_todosLosTurnos_menos1 = ''
sentidoY_en_todosLosTurnos_menos1 = ''
sentidoB_en_todosLosTurnos_menos1 = ''

#Comienza en B
for turno in sentidoB_en_diferentes_turnos:
    sentidoB_en_todosLosTurnos_menos1 = "(" + sentidoB_en_todosLosTurnos_menos1 + "Y" + caminos.escribir('-' + turno) + ")"

    debe_comenzar_en_b = "(" + caminos.escribir(atomoB0) + "Y" + sentidoB_en_todosLosTurnos_menos1 + ")"

#Comienza en Y
for turno in sentidoY_en_diferentes_turnos:
    sentidoY_en_todosLosTurnos_menos1 = "(" + sentidoY_en_todosLosTurnos_menos1 + "Y" + caminos.escribir('-' + turno) + ")"

    debe_comenzar_en_y = "(" + caminos.escribir(atomoY0) + "Y" + sentidoY_en_todosLosTurnos_menos1 + ")"

#Comienza en P
for turno in sentidop_en_diferentes_turnos:
    sentido_p_en_todosLosTurnos_menos1 = "(" + sentido_p_en_todosLosTurnos_menos1 + caminos.escribir('-' + turno) + "Y" + ")"

    debe_comenzar_en_p = "(" + caminos.escribir(atomo1) + "Y" + sentido_p_en_todosLosTurnos_menos1 + ")"



#print(sentido_p_en_todosLosTurnos_menos1)
print(debe_comenzar_en_p)
print("")
print(debe_comenzar_en_y)
print("")
print(debe_comenzar_en_b)
# Out:
# (El caminante, pasa por el puente [0] en el turno [0], hacia la dirección[0]Y((((El caminante, pasa por el puente [0] no en el turno [1], hacia la dirección[0]Y)El caminante, pasa por el puente [0] no en el turno [2], hacia la dirección[0]Y)El caminante, pasa por el puente [0] no en el turno [3], hacia la dirección[0]Y)El caminante, pasa por el puente [0] no en el turno [4], hacia la dirección[0]Y))
#
# (El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[1]Y((((YEl caminante, pasa por el puente [3] no en el turno [1], hacia la dirección[1])YEl caminante, pasa por el puente [3] no en el turno [2], hacia la dirección[1])YEl caminante, pasa por el puente [3] no en el turno [3], hacia la dirección[1])YEl caminante, pasa por el puente [3] no en el turno [4], hacia la dirección[1]))
#
# ...

# %%
#Regla 2
l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
       "y":None, 'b':None, 'c':None}

puente1 = [("p", T[0]), ("q", T[0])]
opc1 = random.choice(puente1)
print("La letra que escogio es:",opc1)

puente2 = [("s", T[0]), ("r", T[0])]
opc2 = random.choice(puente2)
print("La letra que escogio es:",opc2)

puente3 = [("u", T[0]), ("t", T[0])]
opc3 = random.choice(puente3)
print("La letra que escogio es:",opc3)

puente4 = [("y", T[0]), ("x", T[0])]
opc4 = random.choice(puente4)
print("La letra que escogio es:",opc4)

puente5 = [("b", T[0]), ("c", T[0])]
opc5 = random.choice(puente5)
print("La letra que escogio es:",opc5)
             
#Puente 1
print()
print("Puente 1")
if opc1 == ("p",T[0]):
    l_p["p"] = True
    l_p["q"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["p"] = False
            l_p["q"] = False
            print("Turno 2")
            print(l_p)
else: #opc1 == ("q",T[0])
    l_p["q"] = True
    l_p["p"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["p"] = False
            l_p["q"] = False
            print("Turno 2")
            print(l_p)
    


#Puente 2
print()
print("Puente 2")
if opc2 == ("s",T[0]):
    l_p["s"] = True
    l_p["r"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["s"] = False
            l_p["r"] = False
            print("Turno 2")
            print(l_p)
elif opc2 == ("r",T[0]):
    l_p["r"] = True
    l_p["s"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["r"] = False
            l_p["s"] = False
            print("Turno 2")
            print(l_p)

#Puente 3
print()
print("Puente 3")
if opc3 == ("u",T[0]):
    l_p["u"] = True
    l_p["t"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["u"] = False
            l_p["t"] = False
            print("Turno 2")
            print(l_p)
elif opc3 == ("t",T[0]):
    l_p["t"] = True
    l_p["u"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["u"] = False
            l_p["t"] = False
            print("Turno 2")
            print(l_p)

#Puente 4
print()
print("Puente 4")
if opc4 == ("y",T[0]):
    l_p["y"] = True
    l_p["x"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["y"] = False
            l_p["x"] = False
            print("Turno 2")
            print(l_p)
elif opc4 == ("x",T[0]):
    l_p["x"] = True
    l_p["y"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["y"] = False
            l_p["x"] = False
            print("Turno 2")
            print(l_p)

#Puente 5
print()
print("Puente 5")
if opc5 == ("b",T[0]):
    l_p["b"] = True
    l_p["c"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["b"] = False
            l_p["c"] = False
            print("Turno 2")
            print(l_p)
elif opc5 == ("c",T[0]):
    l_p["c"] = True
    l_p["b"] = False
    print("Turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["b"] = False
            l_p["c"] = False
            print("Turno 2")
            print(l_p)

#la l indica el numero del turno.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       1 #Regla 2
#       2 l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
#       3        "y":None, 'b':None, 'c':None}
# ----> 5 puente1 = [("p", T[0]), ("q", T[0])]
#       6 opc1 = random.choice(puente1)
#       7 print("La letra que escogio es:",opc1)
#
# NameError: name 'T' is not defined

# %% [markdown]
# # Regla 3:
# $$(p_{1} \vee r_{1}\vee b_{1}) \wedge (u_{5} \vee s_{5} \vee y_{5})  $$

# %%
#Creación de la regla 3. (Se debe iniciar por (p o y o b) y terminar en (u o s o y)
caminos_iniciales = [debe_comenzar_en_p, debe_comenzar_en_y, debe_comenzar_en_b]
termina_enU = caminos.P([2, 4, 1])
termina_enS = caminos.P([1,4,1])
termina_enY = caminos.P([3,4,1])
caminos_finales = [termina_enU, termina_enS, termina_enY]

regla3 = ''
regla3 = "("+ "(" + "("  + caminos.P([0,0,0])  +  "O" + caminos.P([3,1,0]) + ")" + "O" +  caminos.P([4,0,0]) +")" + "Y" + "(" + termina_enU + "O" + "(" +termina_enS + "O" + termina_enY + ")" + ")" + ")"
print(inorder_to_tree(regla3))
S = tseitin(regla3)
I = {}
dpll(S, I)
#walkSAT(S)
# Out:
# (((ĀOĈ)OĄ)Y(įO(ĮOİ)))
# ('Satisfacible',
#  {'Ĵ': True,
#   'ı': True,
#   'ĳ': True,
#   'İ': False,
#   'Ā': False,
#   'Ĉ': False,
#   'Ą': True,
#   'į': True,
#   'Į': False,
#   'Ĳ': False})

# %%
#MAPA GENERAL
"""
print("\                                                                              /")
print(" \                                                                            /")
print("  \_____     /\    __________________________________________    /\    _____/")
print("        \    |    /                                          \    |   /")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("   _____/    \/   \__________                      __________/   \/   \_____ ")
print("  |                          |                    |                         |")
print("  |                          |                    |                         |")
print("  |                          |____________________|                         |")
print("  |                                                                         |")
print("  |                        <------------------------>                       |")
print("  |                                                                         |")
print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
print("  |                          |                    |                         |")
print("  |_____    /\     __________|                    |__________    /\    _____|")
print("        \    |    /                                          \    |   /")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("        |    |    |                                          |    |   |")
print("   _____/   \/    \__________________________________________/   \/   \_____ ")
print("  /                                                                         \ ")
print(" /                                                                           \ ")
print("/                                                                             \ ")
"""

def interpretacion1():
    # inter1 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,"y":False, 'b':True, 'c':False}
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________     2    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    1    \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        <------------------------3                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____     4     __________|                    |__________    /\    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/    5   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")

def interpretacion2():
    #inter2 = {"p": True, "q":False , "r":False, "s":True, "t":True, "u":False, "x":False,"y":True, 'b':False, 'c':True}
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________     2    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    1    \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        5----------------------->                        |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____     /\    __________|                    |__________     3    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    4    \__________________________________________/   \/    \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")

def interpretacion3():
    #inter3 = {"p": False, "q":True , "r":True, "s":False, "t":False, "u":True, "x":False,"y":True, 'b':True, 'c':False}
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     3      _________________________________________    /\    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    \/   \__________                      __________/    2   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                         1----------------------->                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____     4     __________|                    |__________    /\    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/    5   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")


def interpretacion4():
    #inter4 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,"y":False, 'b':False, 'c':True}
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________     5     _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    4    \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        1 ----------------------->                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____    /\     __________|                    |__________     2    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    3    \__________________________________________/   \/   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")


def interpretacion5():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     /\    __________________________________________     5    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    4    \__________                      __________/   \/   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        <----------------------- 3                       |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____     1     __________|                    |__________    /\    _____|")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/    2   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")

def interpretacion6():
    print("\                                                                              /")
    print(" \                                                                            /")
    print("  \_____     4     __________________________________________    /\    _____/")
    print("        \    |    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/    \/     \________                      __________/    3   \_____ ")
    print("  |                          |                    |                         |")
    print("  |                          |                    |                         |")
    print("  |                          |____________________|                         |")
    print("  |                                                                         |")
    print("  |                        5 ---------------------->                        |")
    print("  |                                                                         |")
    print("  |                          |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|                         |")
    print("  |                          |                    |                         |")
    print("  |_____           __________|                    |__________    /\    _____|")
    print("        \    1    /                                          \    |   /")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("        |    |    |                                          |    |   |")
    print("   _____/   \/    \__________________________________________/    2   \_____ ")
    print("  /                                                                         \ ")
    print(" /                                                                           \ ")
    print("/                                                                             \ ")


def visualizaciones(inter):
    #puente  (A-C)
    inter1 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,
        "y":False, 'b':True, 'c':False}
    inter2 = {"p": True, "q":False , "r":False, "s":True, "t":True, "u":False, "x":False,
        "y":True, 'b':False, 'c':True}
    #puente (A_D)
    inter3 = {"p": False, "q":True , "r":True, "s":False, "t":False, "u":True, "x":False,
        "y":True, 'b':True, 'c':False}
    inter4 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,
        "y":False, 'b':False, 'c':True}
    #puente (A-B)
    inter5 = {"p": True, "q":False , "r":False, "s":True, "t":False, "u":True, "x":True,
        "y":False, 'b':True, 'c':False}
    inter6 = {"p": False, "q":True , "r":True, "s":False, "t":False, "u":True, "x":False,
        "y":True, 'b':True, 'c':False}
    n_inter = {}
    for i in inter:
        val = ((i,inter[i]))
        if val ==("p", True):
            n_inter["p"] = True
            n_inter["q"] = False
        if val ==("q", True):
            n_inter["p"] = False
            n_inter["q"] = True
        if val ==("r", True):
            n_inter["r"] = True
            n_inter["s"] = False
        if val ==("s", True):
            n_inter["s"] = True
            n_inter["r"] = False
        if val ==("t", True):
            n_inter["t"] = True
            n_inter["u"] = False
        if val ==("u", True):
            n_inter["u"] = True
            n_inter["t"] = False
        if val ==("x", True):
            n_inter["x"] = True
            n_inter["y"] = False
        if val ==("y", True):
            n_inter["y"] = True
            n_inter["x"] = False
        if val ==("b", True):
            n_inter["b"] = True
            n_inter["c"] = False
        if val ==("c", True):
            n_inter["c"] = True
            n_inter["b"] = False
    print(n_inter)
    if n_inter == inter1:
        interpretacion1()
    elif n_inter == inter2:
        interpretacion2()
    elif n_inter == inter3:
        interpretacion3()
    elif n_inter == inter4:
        interpretacion4()
    elif n_inter == inter5:
        interpretacion5()
    elif n_inter == inter6:
        interpretacion6()



interp = {'b': True, 'p': True, 's': True, 'u': True, 'x': True}
p = visualizaciones(interp)
# Out:
# {'b': True, 'c': False, 'p': True, 'q': False, 's': True, 'r': False, 'u': True, 't': False, 'x': True, 'y': False}
# \                                                                              /
#  \                                                                            /
#   \_____     /\    __________________________________________     2    _____/
#         \    |    /                                          \    |   /
#         |    |    |                                          |    |   |
#         |    |    |                                          |    |   |
#         |    |    |                                          |    |   |
#         |    |    |                                          |    |   |
#    _____/    1    \__________                      __________/   \/   \_____
#   |                          |                    |                         |
#   |                          |                    |                         |
# ...

# %% [markdown]
# # Regla 4
# $$ \bigvee_{{i}\in\texttt{T-5}} (p_i \to s_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} y_i \to (r_{i+1} \vee t_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} (b_i \to u_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} q_i \to (y_{i+1} \vee b_{i+1}) \wedge  \bigvee_{{i}\in\texttt{T-5}} c_i \to (y_{i+1} \vee p_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} x_i \to (p_{i+1} \vee b_{i+1}) \wedge $$

# %% [markdown]
# $$ \bigvee_{{i}\in\texttt{T-5}} s_i \to (x_{i+1} \vee t_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} (r_i \to q_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} u_i \to (x_{i+1} \vee r_{i+1}) \wedge \bigvee_{{i}\in\texttt{T-5}} (t_i \to c_{i+1}) $$

# %%
# R E G L A 4 ----------
puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]
n_puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]

atomoP = caminos.P([0,0,0]) #Ā
atomoQ = caminos.P([0,0,1]) #ę
atomoS = caminos.P([1,0,0]) #ā
atomoR = caminos.P([1,0,1]) #Ě
atomoU = caminos.P([2,0,0]) #Ă
atomoT = caminos.P([2,0,1]) #ě
atomoX = caminos.P([3,0,0]) #ă
atomoY = caminos.P([3,0,1]) #Ĝ
atomoB = caminos.P([4,0,0]) #Ą
atomoC = caminos.P([4,0,1]) #ĝ

p = caminos.escribir(atomoP)
q = caminos.escribir(atomoQ)
r = caminos.escribir(atomoR)
s = caminos.escribir(atomoS)
t = caminos.escribir(atomoT)
u = caminos.escribir(atomoU)
x = caminos.escribir(atomoX)
y = caminos.escribir(atomoY)
b = caminos.escribir(atomoB)
c = caminos.escribir(atomoC)

msn = ""

for i in range(Nx-1):
    opc = random.choice(n_puentes)
    if opc == ("p",T[0]):
        msn += "{0} y {1} ".format(p, s)

    elif opc == ("q",T[0]):
        msn += "{0} Y ({1} o {2}) ".format(q,y,b)

    elif opc == ("s",T[0]):
        msn += "{0} Y ({1} o {2}) ".format(s,x,t)

    elif opc == ("r", T[0]):
        msn += "{0} Y {1} ".format(r,q)

    elif opc == ("u",T[0]):
        msn += "{0} Y ({1} O {2}) ".format(u,x,r)

    elif opc == ("t", T[0]):
        msn += "{0} Y {1} ".format(t,c)

    elif opc == ("y",T[0]):
        msn += "{0} Y ({1} o {2}) ".format(y,r,t)

    elif opc == ("x",T[0]):
        msn += "{0} Y ({1} o el sentido{2}) ".format(x,p,b)

    elif opc == ("b", T[0]):
        msn += "{0} Y {1} ".format(b, u)

    elif opc == ("c",T[0]):
        msn += "{0} Y ({1} O {2}) ".format(c,y,p)

    n_puentes.remove(opc)

print(msn)
atomoP = caminos.P([0,0,0]) #Ā
atomoQ = caminos.P([0,0,1]) #ę
atomoS = caminos.P([1,0,0]) #ā
atomoR = caminos.P([1,0,1]) #Ě
atomoU = caminos.P([2,0,0]) #Ă
atomoT = caminos.P([2,0,1]) #ě
atomoX = caminos.P([3,0,0]) #ă
atomoY = caminos.P([3,0,1]) #Ĝ
atomoB = caminos.P([4,0,0]) #Ą
atomoC = caminos.P([4,0,1]) #ĝ

#forma distinta
regla4 = "("+atomoP+">"+atomoS+")"+"Y"+"("+atomoY+">"+"("+atomoR+"O"+atomoT+")"+")"+"Y"+"("+atomoB+">"+atomoU+")"+"Y"+"("+atomoQ+">"+"("+atomoY+"O"+atomoB+")"+")"+"Y"+"("+atomoC+">"+"("+atomoY+"O"+atomoP+")"+")"+"Y"+"("+atomoX+">"+"("+ atomoP+"O"+atomoB+")"+")"+"Y"+"("+atomoS+">"+"("+atomoX+"O"+atomoT+")"+")"+"Y"+"("+atomoR+">"+atomoQ+")"+"Y"+"("+atomoU+">"+"("+atomoX+"O"+atomoR+")"+")"+"Y"+"("+atomoT+">"+atomoC+")"
inorder_to_tree(regla4)
#tseitin(regla4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # R E G L A 4 ----------
# ----> 2 puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]
#       3 n_puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]
#       5 atomoP = caminos.P([0,0,0]) #Ā
#
# NameError: name 'T' is not defined

# %%
#Regla 4
l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
       "y":None, 'b':None, 'c':None}
puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]
opc = random.choice(puentes)
print("La letra que escogio es:",opc)


if opc == ("p", T[0]):
    l_p["p"] = True
    l_p["q"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["p"] = False
            l_p["s"] = True
            print("turno 2")
            print(l_p)

if opc == ("q", T[0]):
    l_p["q"] = True
    l_p["p"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("y", T[1]), ("b", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("y", T[1]):
                l_p["q"] = False
                l_p["y"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("b", T[1]):
                l_p["q"] = False
                l_p["b"] = True
                print("turno 2")
                print(l_p)

if opc == ("s", T[0]):
    l_p["s"] = True
    l_p["r"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("x", T[1]), ("t", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("x", T[1]):
                l_p["s"] = False
                l_p["x"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("t", T[1]):
                l_p["s"] = False
                l_p["t"] = True
                print("turno 2")
                print(l_p)

if opc == ("r", T[0]):
    l_p["r"] = True
    l_p["s"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["r"] = False
            l_p["q"] = True
            print("turno 2")
            print(l_p)

if opc == ("u", T[0]):
    l_p["u"] = True
    l_p["t"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("x", T[1]), ("r", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("x", T[1]):
                l_p["u"] = False
                l_p["x"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("r", T[1]):
                l_p["u"] = False
                l_p["r"] = True
                print("turno 2")
                print(l_p)

if opc == ("t", T[0]):
    l_p["t"] = True
    l_p["u"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["t"] = False
            l_p["c"] = True
            print("turno 2")
            print(l_p)

if opc == ("y", T[0]):
    l_p["y"] = True
    l_p["x"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("t", T[1]), ("r", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("t", T[1]):
                l_p["y"] = False
                l_p["t"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("r", T[1]):
                l_p["y"] = False
                l_p["r"] = True
                print("turno 2")
                print(l_p)

if opc == ("x", T[0]):
    l_p["x"] = True
    l_p["y"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("p", T[1]), ("b", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("p", T[1]):
                l_p["x"] = False
                l_p["p"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("b", T[1]):
                l_p["x"] = False
                l_p["b"] = True
                print("turno 2")
                print(l_p)

if opc == ("c", T[0]):
    l_p["c"] = True
    l_p["b"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            camino = [("y", T[1]), ("p", T[1])]
            camino_escogido = random.choice(camino)
            if camino_escogido == ("y", T[1]):
                l_p["c"] = False
                l_p["y"] = True
                print("turno 2")
                print(l_p)
            elif camino_escogido == ("p", T[1]):
                l_p["c"] = False
                l_p["p"] = True
                print("turno 2")
                print(l_p)

if opc == ("b", T[0]):
    l_p["b"] = True
    l_p["c"] = False
    print("turno 1")
    print(l_p)
    for i in range(len(T)):
        l = T[i]
        if l == 2:
            l_p["b"] = False
            l_p["u"] = True
            print("turno 2")
            print(l_p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 #Regla 4
#       2 l_p = {"p": None, "q":None , "r":None, "s":None, "t":None, "u":None, "x":None,
#       3        "y":None, 'b':None, 'c':None}
# ----> 4 puentes = [("p", T[0]), ("q", T[0]), ("s",T[0]), ("r", T[0]), ("u", T[0]), ("t", T[0]), ("y", T[0]), ("x", T[0]), ("b", T[0]), ("c", T[0])]
#       5 opc = random.choice(puentes)
#       6 print("La letra que escogio es:",opc)
#
# NameError: name 'T' is not defined

# %%
# R E G L A 5 - - - - - - - - - - - - - - -
atomoP = caminos.P([0,0,0]) #Ā
atomoQ = caminos.P([0,0,1]) #ę
atomoS = caminos.P([1,0,0]) #ā
atomoR = caminos.P([1,0,1]) #Ě
atomoU = caminos.P([2,0,0]) #Ă
atomoT = caminos.P([2,0,1]) #ě
atomoX = caminos.P([3,0,0]) #ă
atomoY = caminos.P([3,0,1]) #Ĝ
atomoB = caminos.P([4,0,0]) #Ą
atomoC = caminos.P([4,0,1]) #ĝ

p = caminos.escribir(atomoP)
q = caminos.escribir(atomoQ)
r = caminos.escribir(atomoR)
s = caminos.escribir(atomoS)
t = caminos.escribir(atomoT)
u = caminos.escribir(atomoU)
x = caminos.escribir(atomoX)
y = caminos.escribir(atomoY)
b = caminos.escribir(atomoB)
c = caminos.escribir(atomoC)

msn = ""
opcs = [p,q,r,s,t,u,x,y,b,c]

for i in opcs:
    posibilidad = random.choice(opcs)
    if posibilidad == p:
        msn += "({0} O NO({1})) ".format(p,q)
    elif posibilidad == q:
        msn += "({0} O NO({1})) ".format(q,p)
    elif posibilidad == r:
        msn += "({0} O NO({1})) ".format(r,s)
    elif posibilidad == s:
        msn += "({0} O NO({1})) ".format(s,r)
    elif posibilidad == t:
        msn += "({0} O NO({1})) ".format(t,u)
    elif posibilidad == u:
        msn += "({0} O NO({1})) ".format(u,t)
    elif posibilidad == x:
        msn += "({0} O NO({1})) ".format(x,y)
    elif posibilidad == y:
        msn += "({0} O NO({1})) ".format(y,x)
    elif posibilidad == b:
        msn += "({0} O NO({1})) ".format(b,x)
    elif posibilidad == c:
        msn += "({0} O NO({1})) ".format(c,b)
print(msn)

#aqui abajo es una forma mas corta, pero es el mismo codigo que el de arriba
msn1 = ""
for i in opcs:
    posibilidad = random.choice(opcs)
    if posibilidad == p:
        msn1 += "({0} O NO({1})) ".format(atomoP,atomoQ)
    elif posibilidad == q:
        msn1 += "({0} O NO({1})) ".format(atomoQ,atomoP)
    elif posibilidad == r:
        msn1 += "({0} O NO({1})) ".format(atomoR,atomoS)
    elif posibilidad == s:
        msn1 += "({0} O NO({1})) ".format(atomoS,atomoR)
    elif posibilidad == t:
        msn1 += "({0} O NO({1})) ".format(atomoT,atomoU)
    elif posibilidad == u:
        msn1 += "({0} O NO({1})) ".format(atomoU,atomoT)
    elif posibilidad == x:
        msn1 += "({0} O NO({1})) ".format(atomoX,atomoY)
    elif posibilidad == y:
        msn1 += "({0} O NO({1})) ".format(atomoY,atomoX)
    elif posibilidad == b:
        msn1 += "({0} O NO({1})) ".format(atomoB,atomoC)
    elif posibilidad == c:
        msn1 += "({0} O NO({1})) ".format(atomoC,atomoB)
print(msn1)
# Out:
# (El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[0] O NO(El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[1])) (El caminante, pasa por el puente [2] en el turno [0], hacia la dirección[0] O NO(El caminante, pasa por el puente [2] en el turno [0], hacia la dirección[1])) (El caminante, pasa por el puente [1] en el turno [0], hacia la dirección[0] O NO(El caminante, pasa por el puente [1] en el turno [0], hacia la dirección[1])) (El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[0] O NO(El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[1])) (El caminante, pasa por el puente [0] en el turno [0], hacia la dirección[0] O NO(El caminante, pasa por el puente [0] en el turno [0], hacia la dirección[1])) (El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[0] O NO(El caminante, pasa por el puente [3] en el turno [0], hacia la dirección[1])) (El caminante, pasa por el puente [1] 
# ...

# %%
#print("Si comienza en", inicial, "entonces termina en", final )
# Out:
# Empieza en: ('y', 1) y acaba en: ('s', 5)
